# %%
import pandas as pd
from random import shuffle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# strategies listed here

teachers = ['coop', 'def', 'tit1', 'tit0', 'disap']*20
teachers = ['coop', 'def', 'tit1', 'tit0', 'disap']*20

# %%
teachers = ['coop', 'def', 'tit1', 'tit0', 'disap']*20
shuffle(teachers)
df = pd.DataFrame(columns=teachers, index=teachers)
# df = pd.DataFrame(columns=shuffle_list, index=shuffle_list)
df[:] = 'empty'
coop_status = 'C'
def_status = 'D'
tit1_status = 'C'
tit0_status = 'C'
disap_status = 'C'
disap_status_horizon = 'C'

for i in range(len(teachers)):
    for j in range(len(teachers)):
        if i == j:
            df.iloc[i][j] = '0, 0'
        else:
            # coop
            if df.columns[i] == 'coop':
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if df.iloc[i-1][j][-1] == '0' and df.iloc[i - 2][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    if df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][0] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    elif df.iloc[i - 1][j][0] == '0':
                        if df.iloc[i - 2][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                                status_two=tit0_status)
                    elif df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                            status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=coop_status,
                                                                        status_two=disap_status)

            # def
            if df.columns[i] == 'def':
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                            status_two=tit1_status)
                    else:
                        if df.iloc[i - 1][j][0] == '0':
                            if df.iloc[i - 2][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two=tit1_status)
                        if df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                            status_two='D')
                    else:
                        if df.iloc[i - 1][j][0] == '0':
                            if df.iloc[i - 2][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                    status_two=tit0_status)
                        if df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                                status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=def_status,
                                                                        status_two=disap_status)
            # tit1
            if df.columns[i] == 'tit1':
                if df.iloc[i][j - 1][-1] == 'D' or df.iloc[i][j - 1][0] == '0' and df.iloc[i][j - 2][-1] == 'D':
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=not tit1_status)
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two='D')
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit0_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=disap_status)
                else:
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i-1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two='D')
                        elif df.iloc[i - 1][j][0] == '0' and df.iloc[i - 2][j][0] == 'D' or df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                                status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit1_status,
                                                                            status_two=disap_status)
            # tit0
            if df.columns[i] == 'tit0':
                if j == 0 or j == 1 and df.iloc[i][j - 1][-1] == '0' \
                        or df.iloc[i][j - 1][0] == '0' and df.iloc[i][j - 2][-1] == 'D' or df.iloc[i][j - 1][-1] == 'D':
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=not tit1_status)
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                status_two='D')
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                        status_two=tit0_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                                    status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one='D',
                                                                            status_two=disap_status)
                else:
                    if df.index[j] == 'coop':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=coop_status)
                    if df.index[j] == 'def':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=def_status)
                    if df.index[j] == 'tit1':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two=tit1_status)
                        else:
                            if df.iloc[i - 1][j][0] == '0':
                                if df.iloc[i - 2][j][0] == 'D':
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                        status_two='D')
                                else:
                                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                        status_two=tit1_status)
                            if df.iloc[i - 1][j][0] == 'D':
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                    status_two='D')
                            else:
                                df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                    status_two=tit1_status)
                    if df.index[j] == 'tit0':
                        if i == 0 or i == 1 and df.iloc[i - 1][j][-1] == '0':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two='D')
                        elif df.iloc[i - 1][j][0] == '0' and df.iloc[i - 2][j][0] == 'D' or df.iloc[i - 1][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                                status_two=tit0_status)
                    if df.index[j] == 'disap':
                        if df.iloc[i - 2][j][0] == 'D' and df.iloc[i - 1][j][0] == 'D':
                            disap_status = 'D'
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=tit0_status,
                                                                            status_two=disap_status)
            # disap
            if df.columns[i] == 'disap':
                if df.iloc[i][j - 2][-1] == 'D' and df.iloc[i][j - 1][-1] == 'D':
                    disap_status_horizon = 'D'
                if df.index[j] == 'coop':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=coop_status)
                if df.index[j] == 'def':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=def_status)
                if df.index[j] == 'tit1':
                    if df.iloc[i-1][j][-1] == '0' and df.iloc[i - 2][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    if df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two=tit1_status)
                if df.index[j] == 'tit0':
                    if i == 0 or i == 1 and df.iloc[i-1][j][0] == '0':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    elif df.iloc[i - 1][j][0] == '0':
                        if df.iloc[i - 2][j][0] == 'D':
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                                status_two='D')
                        else:
                            df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                                status_two=tit0_status)
                    elif df.iloc[i - 1][j][0] == 'D':
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two='D')
                    else:
                        df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                            status_two=tit0_status)
                if df.index[j] == 'disap':
                    df.iloc[i][j] = '{status_one}, {status_two}'.format(status_one=disap_status_horizon,
                                                                        status_two=disap_status)

df.to_csv('df.csv')
df_payoff = df.copy()
for i in range(len(teachers)):
    for j in range(len(teachers)):
        if df_payoff.iloc[i][j] == '0, 0':
            df_payoff.iloc[i][j] = 0
        if df_payoff.iloc[i][j] == 'C, C':
            df_payoff.iloc[i][j] = 3
        if df_payoff.iloc[i][j] == 'C, D':
            df_payoff.iloc[i][j] = -3
        if df_payoff.iloc[i][j] == 'D, C':
            df_payoff.iloc[i][j] = 6
        if df_payoff.iloc[i][j] == 'D, D':
            df_payoff.iloc[i][j] = 0

df_payoff.to_csv('payoffs.csv')
incent = 7
df_incentive = df_payoff.copy()
for i in range(len(teachers)):
    for j in range(len(teachers)):

        if df_incentive.iloc[i][j] == 3:
            df_incentive.iloc[i][j] = 3 + incent
        if df_incentive.iloc[i][j] == -3:
            df_incentive.iloc[i][j] = -3 + incent
df_incentive.to_csv('incentive_7.csv')

# %%
incent = 4
df_incentive_4 = df_payoff.copy()
for i in range(len(teachers)):
    for j in range(len(teachers)):

        if df_incentive_4.iloc[i][j] == 3:
            df_incentive_4.iloc[i][j] = 3 + incent
        if df_incentive_4.iloc[i][j] == -3:
            df_incentive_4.iloc[i][j] = -3 + incent
df_incentive_4.to_csv('incentive_4.csv')

# %%
df.head()
# Out:
#        tit1  tit1  tit1  tit1 disap  tit0  tit1  tit0  coop  tit1  ...   tit0  \
# tit1   0, 0  C, C  C, C  C, C  C, C  C, D  D, C  C, D  D, C  C, C  ...   D, D
# tit1   C, C  0, 0  C, C  C, C  C, C  C, C  C, D  D, D  D, C  C, C  ...   D, D
# tit1   C, C  C, C  0, 0  C, C  C, C  C, C  C, C  C, D  D, C  C, C  ...   D, D
# tit1   C, C  C, C  C, C  0, 0  C, D  D, C  C, C  C, C  C, C  C, C  ...   D, D
# disap  C, C  C, C  C, C  C, C  0, 0  C, D  C, C  C, C  C, C  C, C  ...   D, D
#
#       disap  coop  tit1  coop  tit0  tit0  tit0   def  tit1
# tit1   D, C  C, C  C, C  C, C  C, D  D, D  D, D  D, D  D, C
# tit1   D, C  C, C  C, C  C, C  C, C  C, D  D, D  D, D  D, D
# tit1   D, D  D, C  C, C  C, C  C, C  C, C  C, D  D, D  D, D
# tit1   D, D  D, C  C, C  C, C  C, C  C, C  C, C  C, D  D, D
# disap  D, D  D, C  D, C  D, C  D, C  D, C  D, C  D, D  D, D
#
# [5 rows x 100 columns]

# %%
df_payoff.head()
# Out:
#       tit1 tit1 tit1 tit1 disap tit0 tit1 tit0 coop tit1 ...  tit0 disap coop  \
# tit1     0    3    3    3     3   -3    6   -3    6    3 ...     0     6    3
# tit1     3    0    3    3     3    3   -3    0    6    3 ...     0     6    3
# tit1     3    3    0    3     3    3    3   -3    6    3 ...     0     0    6
# tit1     3    3    3    0    -3    6    3    3    3    3 ...     0     0    6
# disap    3    3    3    3     0   -3    3    3    3    3 ...     0     0    6
#
#       tit1 coop tit0 tit0 tit0 def tit1
# tit1     3    3   -3    0    0   0    6
# tit1     3    3    3   -3    0   0    0
# tit1     3    3    3    3   -3   0    0
# tit1     3    3    3    3    3  -3    0
# disap    6    6    6    6    6   0    0
#
# [5 rows x 100 columns]

# %%
data = df_payoff.groupby(df_payoff.index).sum()
fig1, ax1 = plt.subplots()
ax1.set_title('Strategies Comparison (insentives=0)')
ax1.boxplot(data, labels=('coop', 'def', 'disap', 'tit0', 'tit1'))
plt.show()

# %%
df_incentive.head()
# Out:
#       tit1 tit1 tit1 tit1 disap tit0 tit1 tit0 coop tit1 ...  tit0 disap coop  \
# tit1     0   10   10   10    10    4    6    4    6   10 ...     0     6   10
# tit1    10    0   10   10    10   10    4    0    6   10 ...     0     6   10
# tit1    10   10    0   10    10   10   10    4    6   10 ...     0     0    6
# tit1    10   10   10    0     4    6   10   10   10   10 ...     0     0    6
# disap   10   10   10   10     0    4   10   10   10   10 ...     0     0    6
#
#       tit1 coop tit0 tit0 tit0 def tit1
# tit1    10   10    4    0    0   0    6
# tit1    10   10   10    4    0   0    0
# tit1    10   10   10   10    4   0    0
# tit1    10   10   10   10   10   4    0
# disap    6    6    6    6    6   0    0
#
# [5 rows x 100 columns]

# %%
data_in_7 = df_incentive.groupby(df_payoff.index).sum()

# %%
data.index[:]
# Out:
# Index(['coop', 'def', 'disap', 'tit0', 'tit1'], dtype='object')

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Strategies Comparison (insentives=7)')
ax1.boxplot(data_in_7, labels=('coop', 'def', 'disap', 'tit0', 'tit1'))
plt.show()

# %%
data_in_4 = df_incentive_4.groupby(df_payoff.index).sum()
fig1, ax1 = plt.subplots()
ax1.set_title('Strategies Comparison (insentives=4)')
ax1.boxplot(data_in_4, labels=('coop', 'def', 'disap', 'tit0', 'tit1'))
plt.show()
